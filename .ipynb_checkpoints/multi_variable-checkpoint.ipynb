# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('book2.csv')
data
# Out:
#      channel  videos  days  subs  views
# 0  channel 1      30   150  1800  34000
# 1  channel 2      40   212  1950  41000
# 2  channel 3      50   179  2100  42500
# 3  channel 4      60   346  4300  54300
# 4  channel 5      70   280  4200  56000

# %%
v =np.array(data.videos.values)
v
# Out:
# array([30, 40, 50, 60, 70], dtype=int64)

# %%
d = np.array(data.days.values)
s = np.array(data.subs.values)

# %%
model = LinearRegression()
model.fit((data[['videos','days','subs']].values), data.views)
# Out:
# LinearRegression()

# %%
model.predict([[45, 180,3100]])
# Out:
# C:\Users\Mash\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41483.5043287])
